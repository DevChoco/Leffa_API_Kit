# %%
# !ls
# Out:
# 3rdparty   __pycache__	densepose   leffa_test.ipynb  requirements.txt
# LICENSE    anaconda.sh	detectron2  leffa_utils       vton_script.py
# README.md  app.py	in_img	    output
# SCHP	   ckpts	leffa	    preprocess

# %%
# !cd leffa/

# %%
# !pip install -r requirements.txt
# Out:
# Collecting av (from -r requirements.txt (line 1))
#   Downloading av-14.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.7 kB)
# Collecting accelerate (from -r requirements.txt (line 2))
#   Downloading accelerate-1.6.0-py3-none-any.whl.metadata (19 kB)
# Collecting config (from -r requirements.txt (line 3))
#   Downloading config-0.5.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting cloudpickle (from -r requirements.txt (line 4))
#   Downloading cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting diffusers (from -r requirements.txt (line 5))
#   Downloading diffusers-0.33.1-py3-none-any.whl.metadata (19 kB)
# Collecting einops (from -r requirements.txt (line 6))
#   Downloading einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting fvcore (from -r requirements.txt (line 7))
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio (from -r requirements.txt (line 8))
#   Downloading gradio-5.24.0-py3-none-any.whl.metadata (16 kB)
# Collecting gradio-client (from -r requirements.txt (line 9))
#   Downloading gradio_client-1.8.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting imageio (from -r requirements.txt (line 10))
#   Downloading imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting matplotlib (from -r requirements.txt (line 11))
#   Downloading matplotlib-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting numpy (from -r requirements.txt (line 12))
#   Downloading numpy-2.2.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting omegaconf (from -r requirements.txt (line 13))
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting onnxruntime (from -r requirements.txt (line 14))
#   Downloading onnxruntime-1.21.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting opencv-python (from -r requirements.txt (line 15))
#   Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting pandas (from -r requirements.txt (line 16))
#   Downloading pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting pillow (from -r requirements.txt (line 17))
#   Downloading pillow-11.1.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting pycocotools (from -r requirements.txt (line 18))
#   Downloading pycocotools-2.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: pyyaml in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from -r requirements.txt (line 19)) (6.0.2)
# Requirement already satisfied: psutil in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from -r requirements.txt (line 20)) (7.0.0)
# Collecting peft (from -r requirements.txt (line 21))
#   Downloading peft-0.15.1-py3-none-any.whl.metadata (13 kB)
# Collecting regex==2024.5.15 (from -r requirements.txt (line 22))
#   Downloading regex-2024.5.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Collecting safetensors (from -r requirements.txt (line 23))
#   Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting scikit-image (from -r requirements.txt (line 24))
#   Downloading scikit_image-0.25.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting scipy (from -r requirements.txt (line 25))
#   Downloading scipy-1.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting timm (from -r requirements.txt (line 26))
#   Downloading timm-1.0.15-py3-none-any.whl.metadata (52 kB)
# Collecting tokenizers (from -r requirements.txt (line 27))
#   Downloading tokenizers-0.21.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting torch (from -r requirements.txt (line 28))
#   Downloading torch-2.6.0-cp310-cp310-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting torchaudio (from -r requirements.txt (line 29))
#   Downloading torchaudio-2.6.0-cp310-cp310-manylinux1_x86_64.whl.metadata (6.6 kB)
# Collecting torchmetrics (from -r requirements.txt (line 30))
#   Downloading torchmetrics-1.7.1-py3-none-any.whl.metadata (21 kB)
# Collecting torchvision (from -r requirements.txt (line 31))
#   Downloading torchvision-0.21.0-cp310-cp310-manylinux1_x86_64.whl.metadata (6.1 kB)
# Collecting tqdm (from -r requirements.txt (line 32))
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting transformers (from -r requirements.txt (line 33))
#   Downloading transformers-4.51.1-py3-none-any.whl.metadata (38 kB)
# Collecting triton (from -r requirements.txt (line 34))
#   Downloading triton-3.3.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging>=20.0 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from accelerate->-r requirements.txt (line 2)) (24.2)
# Collecting huggingface-hub>=0.21.0 (from accelerate->-r requirements.txt (line 2))
#   Downloading huggingface_hub-0.30.2-py3-none-any.whl.metadata (13 kB)
# Collecting importlib-metadata (from diffusers->-r requirements.txt (line 5))
#   Downloading importlib_metadata-8.6.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting filelock (from diffusers->-r requirements.txt (line 5))
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: requests in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from diffusers->-r requirements.txt (line 5)) (2.32.3)
# Collecting yacs>=0.1.6 (from fvcore->-r requirements.txt (line 7))
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Collecting termcolor>=1.1 (from fvcore->-r requirements.txt (line 7))
#   Downloading termcolor-3.0.1-py3-none-any.whl.metadata (6.1 kB)
# Collecting tabulate (from fvcore->-r requirements.txt (line 7))
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting iopath>=0.1.7 (from fvcore->-r requirements.txt (line 7))
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#   Preparing metadata (setup.py) ... done
# Collecting aiofiles<25.0,>=22.0 (from gradio->-r requirements.txt (line 8))
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from gradio->-r requirements.txt (line 8)) (4.9.0)
# Collecting fastapi<1.0,>=0.115.2 (from gradio->-r requirements.txt (line 8))
#   Downloading fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio->-r requirements.txt (line 8))
#   Downloading ffmpy-0.5.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting groovy~=0.1 (from gradio->-r requirements.txt (line 8))
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from gradio->-r requirements.txt (line 8)) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from gradio->-r requirements.txt (line 8)) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from gradio->-r requirements.txt (line 8)) (3.0.2)
# Collecting orjson~=3.0 (from gradio->-r requirements.txt (line 8))
#   Downloading orjson-3.10.16-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
# Collecting pydantic<2.12,>=2.0 (from gradio->-r requirements.txt (line 8))
#   Downloading pydantic-2.11.3-py3-none-any.whl.metadata (65 kB)
# Collecting pydub (from gradio->-r requirements.txt (line 8))
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio->-r requirements.txt (line 8))
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting ruff>=0.9.3 (from gradio->-r requirements.txt (line 8))
#   Downloading ruff-0.11.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio->-r requirements.txt (line 8))
#   Downloading safehttpx-0.1.6-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio->-r requirements.txt (line 8))
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio->-r requirements.txt (line 8))
#   Downloading starlette-0.46.1-py3-none-any.whl.metadata (6.2 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio->-r requirements.txt (line 8))
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting typer<1.0,>=0.12 (from gradio->-r requirements.txt (line 8))
#   Downloading typer-0.15.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions~=4.0 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from gradio->-r requirements.txt (line 8)) (4.13.1)
# Collecting uvicorn>=0.14.0 (from gradio->-r requirements.txt (line 8))
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting fsspec (from gradio-client->-r requirements.txt (line 9))
#   Downloading fsspec-2025.3.2-py3-none-any.whl.metadata (11 kB)
# Collecting websockets<16.0,>=10.0 (from gradio-client->-r requirements.txt (line 9))
#   Downloading websockets-15.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->-r requirements.txt (line 11))
#   Downloading contourpy-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib->-r requirements.txt (line 11))
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->-r requirements.txt (line 11))
#   Downloading fonttools-4.57.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (102 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->-r requirements.txt (line 11))
#   Downloading kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->-r requirements.txt (line 11))
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 11)) (2.9.0.post0)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf->-r requirements.txt (line 13))
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#   Preparing metadata (setup.py) ... done
# Collecting coloredlogs (from onnxruntime->-r requirements.txt (line 14))
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime->-r requirements.txt (line 14))
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting protobuf (from onnxruntime->-r requirements.txt (line 14))
#   Downloading protobuf-6.30.2-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting sympy (from onnxruntime->-r requirements.txt (line 14))
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting pytz>=2020.1 (from pandas->-r requirements.txt (line 16))
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->-r requirements.txt (line 16))
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting networkx>=3.0 (from scikit-image->-r requirements.txt (line 24))
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image->-r requirements.txt (line 24))
#   Downloading tifffile-2025.3.30-py3-none-any.whl.metadata (32 kB)
# Collecting lazy-loader>=0.4 (from scikit-image->-r requirements.txt (line 24))
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->-r requirements.txt (line 28))
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->-r requirements.txt (line 28))
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->-r requirements.txt (line 28))
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->-r requirements.txt (line 28))
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->-r requirements.txt (line 28))
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->-r requirements.txt (line 28))
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->-r requirements.txt (line 28))
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->-r requirements.txt (line 28))
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->-r requirements.txt (line 28))
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.2 (from torch->-r requirements.txt (line 28))
#   Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch->-r requirements.txt (line 28))
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch->-r requirements.txt (line 28))
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->-r requirements.txt (line 28))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton (from -r requirements.txt (line 34))
#   Downloading triton-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Collecting sympy (from onnxruntime->-r requirements.txt (line 14))
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->onnxruntime->-r requirements.txt (line 14))
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics->-r requirements.txt (line 30))
#   Downloading lightning_utilities-0.14.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from anyio<5.0,>=3.0->gradio->-r requirements.txt (line 8)) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from anyio<5.0,>=3.0->gradio->-r requirements.txt (line 8)) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from anyio<5.0,>=3.0->gradio->-r requirements.txt (line 8)) (1.3.1)
# Requirement already satisfied: certifi in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from httpx>=0.24.1->gradio->-r requirements.txt (line 8)) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from httpx>=0.24.1->gradio->-r requirements.txt (line 8)) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio->-r requirements.txt (line 8)) (0.14.0)
# Collecting portalocker (from iopath>=0.1.7->fvcore->-r requirements.txt (line 7))
#   Downloading portalocker-3.1.1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: setuptools in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from lightning-utilities>=0.8.0->torchmetrics->-r requirements.txt (line 30)) (75.8.0)
# Collecting annotated-types>=0.6.0 (from pydantic<2.12,>=2.0->gradio->-r requirements.txt (line 8))
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.1 (from pydantic<2.12,>=2.0->gradio->-r requirements.txt (line 8))
#   Downloading pydantic_core-2.33.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<2.12,>=2.0->gradio->-r requirements.txt (line 8))
#   Downloading typing_inspection-0.4.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.5 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 11)) (1.17.0)
# Collecting click>=8.0.0 (from typer<1.0,>=0.12->gradio->-r requirements.txt (line 8))
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio->-r requirements.txt (line 8))
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<1.0,>=0.12->gradio->-r requirements.txt (line 8))
#   Downloading rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime->-r requirements.txt (line 14))
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting zipp>=3.20 (from importlib-metadata->diffusers->-r requirements.txt (line 5))
#   Downloading zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from requests->diffusers->-r requirements.txt (line 5)) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from requests->diffusers->-r requirements.txt (line 5)) (2.3.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0,>=0.12->gradio->-r requirements.txt (line 8))
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->-r requirements.txt (line 8)) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio->-r requirements.txt (line 8))
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading regex-2024.5.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (775 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 775.1/775.1 kB 33.3 MB/s eta 0:00:00
# Downloading av-14.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.7/34.7 MB 83.1 MB/s eta 0:00:0000:0100:01
# Downloading accelerate-1.6.0-py3-none-any.whl (354 kB)
# Downloading config-0.5.1-py2.py3-none-any.whl (20 kB)
# Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Downloading diffusers-0.33.1-py3-none-any.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 10.7 MB/s eta 0:00:00a 0:00:01
# Downloading einops-0.8.1-py3-none-any.whl (64 kB)
# Downloading gradio-5.24.0-py3-none-any.whl (46.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 69.3 MB/s eta 0:00:00a 0:00:01
# Downloading gradio_client-1.8.0-py3-none-any.whl (322 kB)
# Downloading imageio-2.37.0-py3-none-any.whl (315 kB)
# Downloading matplotlib-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 76.6 MB/s eta 0:00:00
# Downloading numpy-2.2.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 78.8 MB/s eta 0:00:0000:01
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Downloading onnxruntime-1.21.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 79.6 MB/s eta 0:00:00
# Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 76.8 MB/s eta 0:00:0000:0100:01
# Downloading pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 82.9 MB/s eta 0:00:00
# Downloading pillow-11.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 78.3 MB/s eta 0:00:00
# Downloading pycocotools-2.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (427 kB)
# Downloading peft-0.15.1-py3-none-any.whl (411 kB)
# Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
# Downloading scikit_image-0.25.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 41.8 MB/s eta 0:00:00a 0:00:01
# Downloading scipy-1.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.6/37.6 MB 43.8 MB/s eta 0:00:00a 0:00:01
# Downloading timm-1.0.15-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 81.1 MB/s eta 0:00:00
# Downloading tokenizers-0.21.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 78.1 MB/s eta 0:00:00
# Downloading torch-2.6.0-cp310-cp310-manylinux1_x86_64.whl (766.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.7/766.7 MB 65.2 MB/s eta 0:00:0000:0100:01
# Downloading triton-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (253.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.1/253.1 MB 76.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 64.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 70.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 73.0 MB/s eta 0:00:00a 0:00:01
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 27.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 66.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 57.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 56.6 MB/s eta 0:00:00a 0:00:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 60.9 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 74.5 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl (150.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 62.8 MB/s eta 0:00:00a 0:00:01
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 78.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 80.1 MB/s eta 0:00:00a 0:00:01
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 91.4 MB/s eta 0:00:00
# Downloading torchaudio-2.6.0-cp310-cp310-manylinux1_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 82.6 MB/s eta 0:00:00
# Downloading torchmetrics-1.7.1-py3-none-any.whl (961 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 961.5/961.5 kB 60.2 MB/s eta 0:00:00
# Downloading torchvision-0.21.0-cp310-cp310-manylinux1_x86_64.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 28.4 MB/s eta 0:00:00a 0:00:01
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading transformers-4.51.1-py3-none-any.whl (10.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 88.1 MB/s eta 0:00:00
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading contourpy-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (324 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fastapi-0.115.12-py3-none-any.whl (95 kB)
# Downloading fonttools-4.57.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 75.3 MB/s eta 0:00:00
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading huggingface_hub-0.30.2-py3-none-any.whl (481 kB)
# Downloading fsspec-2025.3.2-py3-none-any.whl (194 kB)
# Downloading kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 66.7 MB/s eta 0:00:00
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading lightning_utilities-0.14.3-py3-none-any.whl (28 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 66.3 MB/s eta 0:00:00
# Downloading orjson-3.10.16-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (132 kB)
# Downloading pydantic-2.11.3-py3-none-any.whl (443 kB)
# Downloading pydantic_core-2.33.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 13.3 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading ruff-0.11.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 90.2 MB/s eta 0:00:00
# Downloading safehttpx-0.1.6-py3-none-any.whl (8.7 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.46.1-py3-none-any.whl (71 kB)
# Downloading termcolor-3.0.1-py3-none-any.whl (7.2 kB)
# Downloading tifffile-2025.3.30-py3-none-any.whl (226 kB)
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading typer-0.15.2-py3-none-any.whl (45 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
# Downloading websockets-15.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (181 kB)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading ffmpy-0.5.0-py3-none-any.whl (6.0 kB)
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading importlib_metadata-8.6.1-py3-none-any.whl (26 kB)
# Downloading protobuf-6.30.2-cp39-abi3-manylinux2014_x86_64.whl (316 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 38.9 MB/s eta 0:00:00
# Downloading rich-14.0.0-py3-none-any.whl (243 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# Downloading zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Downloading portalocker-3.1.1-py3-none-any.whl (19 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: fvcore, antlr4-python3-runtime, iopath
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61443 sha256=68a28d3fbed96cf982ec546ed65bb40de78a3f6496d3d6fba12ffdcac091d612
#   Stored in directory: /home/lab/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144591 sha256=74f1c9cf7812dc4d5f428d19bb2f270d483baf7e4bfe6fc02b74703dcfab5f23
#   Stored in directory: /home/lab/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31570 sha256=0d40d72a325ffebb3387abd761c7a698f7c796932ea4cef00c61566a9095d8e5
#   Stored in directory: /home/lab/.cache/pip/wheels/9a/a3/b6/ac0fcd1b4ed5cfeb3db92e6a0e476cfd48ed0df92b91080c1d
# Successfully built fvcore antlr4-python3-runtime iopath
# Installing collected packages: triton, pytz, pydub, nvidia-cusparselt-cu12, mpmath, flatbuffers, config, antlr4-python3-runtime, zipp, yacs, websockets, tzdata, typing-inspection, tqdm, tomlkit, termcolor, tabulate, sympy, shellingham, semantic-version, safetensors, ruff, regex, python-multipart, pyparsing, pydantic-core, protobuf, portalocker, pillow, orjson, omegaconf, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, mdurl, lightning-utilities, lazy-loader, kiwisolver, humanfriendly, groovy, fsspec, fonttools, filelock, ffmpy, einops, cycler, cloudpickle, click, av, annotated-types, aiofiles, uvicorn, tifffile, starlette, scipy, pydantic, pandas, opencv-python, nvidia-cusparse-cu12, nvidia-cudnn-cu12, markdown-it-py, iopath, importlib-metadata, imageio, huggingface-hub, contourpy, coloredlogs, tokenizers, scikit-image, safehttpx, rich, onnxruntime, nvidia-cusolver-cu12, matplotlib, gradio-client, fvcore, fastapi, diffusers, typer, transformers, torch, pycocotools, torchvision, torchmetrics, torchaudio, gradio, accelerate, timm, peft
# Successfully installed accelerate-1.6.0 aiofiles-24.1.0 annotated-types-0.7.0 antlr4-python3-runtime-4.9.3 av-14.3.0 click-8.1.8 cloudpickle-3.1.1 coloredlogs-15.0.1 config-0.5.1 contourpy-1.3.1 cycler-0.12.1 diffusers-0.33.1 einops-0.8.1 fastapi-0.115.12 ffmpy-0.5.0 filelock-3.18.0 flatbuffers-25.2.10 fonttools-4.57.0 fsspec-2025.3.2 fvcore-0.1.5.post20221221 gradio-5.24.0 gradio-client-1.8.0 groovy-0.1.2 huggingface-hub-0.30.2 humanfriendly-10.0 imageio-2.37.0 importlib-metadata-8.6.1 iopath-0.1.10 kiwisolver-1.4.8 lazy-loader-0.4 lightning-utilities-0.14.3 markdown-it-py-3.0.0 matplotlib-3.10.1 mdurl-0.1.2 mpmath-1.3.0 networkx-3.4.2 numpy-2.2.4 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-cusparselt-cu12-0.6.2 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 omegaconf-2.3.0 onnxruntime-1.21.0 opencv-python-4.11.0.86 orjson-3.10.16 pandas-2.2.3 peft-0.15.1 pillow-11.1.0 portalocker-3.1.1 protobuf-6.30.2 pycocotools-2.0.8 pydantic-2.11.3 pydantic-core-2.33.1 pydub-0.25.1 pyparsing-3.2.3 python-multipart-0.0.20 pytz-2025.2 regex-2024.5.15 rich-14.0.0 ruff-0.11.4 safehttpx-0.1.6 safetensors-0.5.3 scikit-image-0.25.2 scipy-1.15.2 semantic-version-2.10.0 shellingham-1.5.4 starlette-0.46.1 sympy-1.13.1 tabulate-0.9.0 termcolor-3.0.1 tifffile-2025.3.30 timm-1.0.15 tokenizers-0.21.1 tomlkit-0.13.2 torch-2.6.0 torchaudio-2.6.0 torchmetrics-1.7.1 torchvision-0.21.0 tqdm-4.67.1 transformers-4.51.1 triton-3.2.0 typer-0.15.2 typing-inspection-0.4.0 tzdata-2025.2 uvicorn-0.34.0 websockets-15.0.1 yacs-0.1.8 zipp-3.21.0

# %%
# !pip install torch torchvision
# !pip install opencv-python
# !pip install imageio
# !pip install scikit-image
# Out:
# Requirement already satisfied: torch in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (2.6.0)
# Requirement already satisfied: torchvision in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (0.21.0)
# Requirement already satisfied: filelock in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from torch) (4.13.1)
# Requirement already satisfied: networkx in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from torchvision) (2.2.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: opencv-python in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from opencv-python) (2.2.4)
# Requirement already satisfied: imageio in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (2.37.0)
# Requirement already satisfied: numpy in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from imageio) (2.2.4)
# Requirement already satisfied: pillow>=8.3.2 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from imageio) (11.1.0)
# Requirement already satisfied: scikit-image in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (0.25.2)
# Requirement already satisfied: numpy>=1.24 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from scikit-image) (2.2.4)
# Requirement already satisfied: scipy>=1.11.4 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from scikit-image) (1.15.2)
# Requirement already satisfied: networkx>=3.0 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from scikit-image) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from scikit-image) (11.1.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from scikit-image) (2025.3.30)
# Requirement already satisfied: packaging>=21 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from scikit-image) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages (from scikit-image) (0.4)

# %%
# !python3 app.py
# Out:
# Fetching 37 files:   0%|                                 | 0/37 [00:00<?, ?it/s]
# model_final_162be9.pkl:   0%|                        | 0.00/256M [00:00<?, ?B/s]
#
# vis_result.png:   0%|                               | 0.00/4.77M [00:00<?, ?B/s]
#
#
# teaser.png:   0%|                                   | 0.00/3.01M [00:00<?, ?B/s]
#
#
#
# README.md: 100%|███████████████████████████| 5.12k/5.12k [00:00<00:00, 52.4MB/s]
#
#
# vis_result.png: 100%|██████████████████████| 4.77M/4.77M [00:00<00:00, 30.8MB/s]
#
#
#
# .gitattributes: 100%|██████████████████████| 1.60k/1.60k [00:00<00:00, 19.4MB/s]
#
#
#
#
# Base-DensePose-RCNN-FPN.yaml: 100%|████████| 1.52k/1.52k [00:00<00:00, 22.6MB/s]
# vis_result.png: 100%|██████████████████████| 4.77M/4.77M [00:00<00:00, 30.3MB/s]
# Fetching 37 files:   3%|▋                        | 1/37 [00:00<00:16,  2.15it/s]
#
#
# teaser.png: 100%|██████████████████████████| 3.01M/3.01M [00:00<00:00, 18.3MB/s]
#
#
# leffa.png: 100%|█████████████████████████████| 996k/996k [00:00<00:00, 14.5MB/s]
#
# model_final_162be9.pkl:   4%|▌              | 10.5M/256M [00:00<00:05, 41.0MB/s]
#
# densepose_rcnn_R_50_FPN_s1x.yaml: 100%|████████| 183/183 [00:00<00:00, 2.61MB/s]
# Fetching 37 files:  19%|████▋                    | 7/37 [00:00<00:01, 15.53it/s]
# model_final_162be9.pkl:   8%|█▏             | 21.0M/256M [00:00<00:04, 58.1MB/s]
#
# 03553_00.jpg:   0%|                                  | 0.00/140k [00:00<?, ?B/s]
#
#
# 02070_00.jpg: 100%|████████████████████████| 64.8k/64.8k [00:00<00:00, 28.4MB/s]
# 03553_00.jpg: 100%|██████████████████████████| 140k/140k [00:00<00:00, 24.9MB/s]
#
#
# 01853_00.jpg: 100%|████████████████████████| 66.8k/66.8k [00:00<00:00, 3.19MB/s]
#
#
# 01350_00.jpg: 100%|████████████████████████| 99.8k/99.8k [00:00<00:00, 88.4MB/s]
#
# model_final_162be9.pkl:  12%|█▊             | 31.5M/256M [00:00<00:03, 68.3MB/s]
#
# 01449_00.jpg: 100%|████████████████████████| 91.3k/91.3k [00:00<00:00, 2.57MB/s]
#
#
# 01486_00.jpg: 100%|████████████████████████| 60.2k/60.2k [00:00<00:00, 5.40MB/s]
#
# model_final_162be9.pkl:  16%|██▍            | 41.9M/256M [00:00<00:02, 75.9MB/s]
#
# 05976_00.jpg:   0%|                                  | 0.00/142k [00:00<?, ?B/s]
#
#
# 05976_00.jpg: 100%|██████████████████████████| 142k/142k [00:00<00:00, 50.3MB/s]
# 01416_00.jpg: 100%|██████████████████████████| 130k/130k [00:00<00:00, 32.1MB/s]
#
#
# 06094_00.jpg: 100%|██████████████████████████| 113k/113k [00:00<00:00, 6.69MB/s]
#
# model_final_162be9.pkl:  20%|███            | 52.4M/256M [00:00<00:02, 81.3MB/s]
#
# 01850_00.jpg: 100%|███████████████████████████| 135k/135k [00:00<00:00, 104MB/s]
#
#
# 01875_00.jpg: 100%|████████████████████████| 83.7k/83.7k [00:00<00:00, 4.49MB/s]
#
#
# 01376_00.jpg:   0%|                                  | 0.00/111k [00:00<?, ?B/s]
#
#
# 02532_00.jpg:   0%|                                  | 0.00/137k [00:00<?, ?B/s]
# 02532_00.jpg: 100%|██████████████████████████| 137k/137k [00:00<00:00, 11.0MB/s]
#
#
#
# 05346_00.jpg:   0%|                                  | 0.00/131k [00:00<?, ?B/s]
#
#
#
# 05346_00.jpg: 100%|██████████████████████████| 131k/131k [00:00<00:00, 47.3MB/s]
# 02902_00.jpg: 100%|██████████████████████████| 113k/113k [00:00<00:00, 70.4MB/s]
# 01376_00.jpg: 100%|██████████████████████████| 111k/111k [00:00<00:00, 3.91MB/s]
#
#
# parsing_atr.onnx:   0%|                              | 0.00/267M [00:00<?, ?B/s]
# model_final_162be9.pkl:  29%|████▎          | 73.4M/256M [00:00<00:02, 85.8MB/s]
#
#
# parsing_lip.onnx:   0%|                              | 0.00/267M [00:00<?, ?B/s]
#
#
#
# body_pose_model.pth:   0%|                           | 0.00/209M [00:00<?, ?B/s]
#
#
#
#
# exp-schp-201908261155-lip.pth:   0%|                 | 0.00/267M [00:00<?, ?B/s]
#
#
#
#
#
# exp-schp-201908301523-atr.pth:   0%|                 | 0.00/267M [00:00<?, ?B/s]
#
#
#
#
#
#
# pose_transfer.pth:   0%|                            | 0.00/20.9G [00:00<?, ?B/s]
#
#
#
#
#
#
#
# scheduler_config.json: 100%|███████████████████| 313/313 [00:00<00:00, 4.64MB/s]
#
# model_final_162be9.pkl:  33%|████▉          | 83.9M/256M [00:01<00:03, 44.8MB/s]
#
#
# parsing_lip.onnx:   4%|▊                    | 10.5M/267M [00:00<00:14, 17.9MB/s]
#
# parsing_atr.onnx:   4%|▊                    | 10.5M/267M [00:00<00:15, 16.6MB/s]
#
#
#
#
#
# exp-schp-201908301523-atr.pth:   4%|▎       | 10.5M/267M [00:00<00:15, 16.9MB/s]
# model_final_162be9.pkl:  37%|█████▌         | 94.4M/256M [00:01<00:04, 40.1MB/s]
#
#
#
#
# exp-schp-201908261155-lip.pth:   4%|▎       | 10.5M/267M [00:00<00:17, 14.6MB/s]
#
#
#
#
#
#
#
# config.json: 100%|█████████████████████████████| 748/748 [00:00<00:00, 10.1MB/s]
#
# model_final_162be9.pkl:  41%|██████▌         | 105M/256M [00:02<00:04, 37.2MB/s]
#
#
# parsing_lip.onnx:   8%|█▋                   | 21.0M/267M [00:01<00:14, 17.1MB/s]
#
#
#
#
#
# exp-schp-201908301523-atr.pth:   8%|▋       | 21.0M/267M [00:01<00:12, 19.6MB/s]
#
#
#
# body_pose_model.pth:   5%|▉                 | 10.5M/209M [00:01<00:23, 8.31MB/s]
# model_final_162be9.pkl:  45%|███████▏        | 115M/256M [00:02<00:04, 34.6MB/s]
#
# parsing_atr.onnx:   8%|█▋                   | 21.0M/267M [00:01<00:18, 13.6MB/s]
#
#
#
#
#
#
#
# config.json: 100%|█████████████████████████████| 552/552 [00:00<00:00, 7.72MB/s]
#
#
#
#
#
# exp-schp-201908261155-lip.pth:   8%|▋       | 21.0M/267M [00:01<00:17, 14.4MB/s]
#
#
#
#
#
# exp-schp-201908301523-atr.pth:  12%|▉       | 31.5M/267M [00:01<00:11, 20.8MB/s]
# model_final_162be9.pkl:  49%|███████▊        | 126M/256M [00:02<00:03, 33.1MB/s]
#
#
# parsing_lip.onnx:  12%|██▍                  | 31.5M/267M [00:01<00:14, 16.3MB/s]
#
#
#
#
#
# exp-schp-201908301523-atr.pth:  16%|█▎      | 41.9M/267M [00:01<00:10, 22.0MB/s]
# model_final_162be9.pkl:  53%|████████▌       | 136M/256M [00:03<00:03, 32.5MB/s]
#
#
#
#
#
#
#
# scheduler_config.json: 100%|███████████████████| 479/479 [00:00<00:00, 6.22MB/s]
#
#
#
#
#
# exp-schp-201908261155-lip.pth:  12%|▉       | 31.5M/267M [00:02<00:16, 14.6MB/s]
#
# parsing_atr.onnx:  12%|██▍                  | 31.5M/267M [00:02<00:20, 11.6MB/s]
#
#
#
#
#
# exp-schp-201908301523-atr.pth:  20%|█▌      | 52.4M/267M [00:02<00:09, 23.3MB/s]
# model_final_162be9.pkl:  57%|█████████▏      | 147M/256M [00:03<00:03, 30.6MB/s]
#
#
# parsing_lip.onnx:  16%|███▎                 | 41.9M/267M [00:02<00:13, 16.3MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   0%|                 | 10.5M/20.9G [00:02<1:20:58, 4.29MB/s]
#
#
#
#
#
#
#
# config.json: 100%|█████████████████████████| 1.93k/1.93k [00:00<00:00, 16.2MB/s]
#
# model_final_162be9.pkl:  61%|█████████▊      | 157M/256M [00:03<00:03, 30.5MB/s]
#
#
#
#
# exp-schp-201908261155-lip.pth:  16%|█▎      | 41.9M/267M [00:02<00:15, 14.6MB/s]
#
#
#
#
#
# exp-schp-201908301523-atr.pth:  24%|█▉      | 62.9M/267M [00:02<00:08, 22.8MB/s]
#
#
# parsing_lip.onnx:  20%|████▏                | 52.4M/267M [00:03<00:11, 18.0MB/s]
#
#
#
#
#
#
#
# config.json: 100%|█████████████████████████████| 659/659 [00:00<00:00, 8.83MB/s]
#
# model_final_162be9.pkl:  66%|██████████▍     | 168M/256M [00:04<00:03, 29.3MB/s]
#
#
#
# body_pose_model.pth:  10%|█▊                | 21.0M/209M [00:03<00:30, 6.18MB/s]
#
#
#
#
#
# exp-schp-201908301523-atr.pth:  27%|██▏     | 73.4M/267M [00:03<00:08, 23.9MB/s]
#
#
# parsing_lip.onnx:  24%|████▉                | 62.9M/267M [00:03<00:10, 18.9MB/s]
#
#
#
#
# exp-schp-201908261155-lip.pth:  20%|█▌      | 52.4M/267M [00:03<00:14, 15.3MB/s]
# model_final_162be9.pkl:  70%|███████████▏    | 178M/256M [00:04<00:02, 27.9MB/s]
#
#
#
#
#
#
#
# virtual_tryon.pth:   0%|                            | 0.00/7.21G [00:00<?, ?B/s]
#
#
#
#
#
# exp-schp-201908301523-atr.pth:  31%|██▌     | 83.9M/267M [00:03<00:07, 23.9MB/s]
#
#
# parsing_lip.onnx:  28%|█████▊               | 73.4M/267M [00:04<00:10, 19.2MB/s]
# model_final_162be9.pkl:  74%|███████████▊    | 189M/256M [00:05<00:02, 26.3MB/s]
#
#
#
#
# exp-schp-201908261155-lip.pth:  24%|█▉      | 62.9M/267M [00:04<00:12, 15.8MB/s]
#
#
#
#
#
# exp-schp-201908301523-atr.pth:  35%|██▊     | 94.4M/267M [00:04<00:07, 23.6MB/s]
#
# parsing_atr.onnx:  16%|███▎                 | 41.9M/267M [00:04<00:27, 8.27MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   0%|                 | 21.0M/20.9G [00:04<1:08:25, 5.08MB/s]
#
#
# parsing_lip.onnx:  31%|██████▌              | 83.9M/267M [00:04<00:09, 19.6MB/s]
# model_final_162be9.pkl:  78%|████████████▍   | 199M/256M [00:05<00:02, 25.5MB/s]
#
#
#
#
#
# exp-schp-201908301523-atr.pth:  39%|███▌     | 105M/267M [00:04<00:06, 23.7MB/s]
#
#
#
#
# exp-schp-201908261155-lip.pth:  27%|██▏     | 73.4M/267M [00:04<00:12, 16.1MB/s]
# model_final_162be9.pkl:  82%|█████████████   | 210M/256M [00:06<00:01, 24.7MB/s]
#
#
# parsing_lip.onnx:  35%|███████▍             | 94.4M/267M [00:05<00:08, 20.3MB/s]
#
#
#
#
#
# exp-schp-201908301523-atr.pth:  43%|███▉     | 115M/267M [00:05<00:06, 23.9MB/s]
#
#
#
#
# exp-schp-201908261155-lip.pth:  31%|██▌     | 83.9M/267M [00:05<00:10, 16.9MB/s]
# model_final_162be9.pkl:  86%|█████████████▊  | 220M/256M [00:06<00:01, 24.1MB/s]
#
#
# parsing_lip.onnx:  39%|████████▋             | 105M/267M [00:05<00:07, 20.3MB/s]
#
#
#
#
#
# exp-schp-201908301523-atr.pth:  47%|████▏    | 126M/267M [00:05<00:06, 23.0MB/s]
# model_final_162be9.pkl:  90%|██████████████▍ | 231M/256M [00:06<00:01, 23.9MB/s]
#
#
#
#
# exp-schp-201908261155-lip.pth:  35%|██▊     | 94.4M/267M [00:05<00:09, 17.6MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   0%|                 | 31.5M/20.9G [00:05<1:00:53, 5.71MB/s]
#
#
# parsing_lip.onnx:  43%|█████████▌            | 115M/267M [00:05<00:07, 21.4MB/s]
#
#
#
#
#
# exp-schp-201908301523-atr.pth:  51%|████▌    | 136M/267M [00:05<00:05, 23.8MB/s]
#
#
# parsing_lip.onnx:  47%|██████████▎           | 126M/267M [00:07<00:09, 14.3MB/s]
# model_final_162be9.pkl:  94%|███████████████ | 241M/256M [00:08<00:00, 14.7MB/s]
#
#
#
#
#
# exp-schp-201908301523-atr.pth:  55%|████▉    | 147M/267M [00:07<00:07, 15.1MB/s]
#
#
#
#
# exp-schp-201908261155-lip.pth:  39%|███▌     | 105M/267M [00:07<00:13, 12.4MB/s]
#
#
#
#
#
# exp-schp-201908301523-atr.pth:  59%|█████▎   | 157M/267M [00:07<00:06, 17.6MB/s]
#
#
# parsing_lip.onnx:  51%|███████████▏          | 136M/267M [00:07<00:08, 16.2MB/s]
# model_final_162be9.pkl:  98%|███████████████▋| 252M/256M [00:08<00:00, 16.1MB/s]
#
#
#
#
# exp-schp-201908261155-lip.pth:  43%|███▉     | 115M/267M [00:07<00:10, 13.9MB/s]
# model_final_162be9.pkl: 100%|████████████████| 256M/256M [00:08<00:00, 28.4MB/s]
# Fetching 37 files:  30%|███████▏                | 11/37 [00:09<00:27,  1.04s/it]
#
#
#
#
#
# exp-schp-201908301523-atr.pth:  63%|█████▋   | 168M/267M [00:07<00:04, 20.1MB/s]
#
#
# parsing_lip.onnx:  55%|████████████          | 147M/267M [00:08<00:06, 18.5MB/s]
# virtual_tryon_dc.pth:   0%|                         | 0.00/7.21G [00:00<?, ?B/s]
#
#
#
#
#
#
# pose_transfer.pth:   0%|                 | 41.9M/20.9G [00:08<1:06:53, 5.19MB/s]
#
#
#
# body_pose_model.pth:  15%|██▋               | 31.5M/209M [00:08<00:54, 3.28MB/s]
#
#
#
#
#
# exp-schp-201908301523-atr.pth:  67%|█████▉   | 178M/267M [00:08<00:04, 21.7MB/s]
#
#
#
#
# exp-schp-201908261155-lip.pth:  47%|████▏    | 126M/267M [00:08<00:09, 15.2MB/s]
#
#
# parsing_lip.onnx:  59%|████████████▉         | 157M/267M [00:08<00:05, 19.5MB/s]
#
#
#
#
#
# exp-schp-201908301523-atr.pth:  71%|██████▎  | 189M/267M [00:08<00:03, 22.6MB/s]
# virtual_tryon_dc.pth:   0%|                | 10.5M/7.21G [00:00<07:34, 15.8MB/s]
#
#
#
#
# exp-schp-201908261155-lip.pth:  51%|████▌    | 136M/267M [00:08<00:07, 16.5MB/s]
#
#
# parsing_lip.onnx:  63%|█████████████▊        | 168M/267M [00:09<00:04, 20.5MB/s]
#
# parsing_atr.onnx:  20%|████▏                | 52.4M/267M [00:09<00:52, 4.10MB/s]
#
#
#
#
#
# exp-schp-201908301523-atr.pth:  74%|██████▋  | 199M/267M [00:09<00:02, 23.0MB/s]
#
#
# parsing_lip.onnx:  67%|██████████████▋       | 178M/267M [00:09<00:04, 22.0MB/s]
#
#
#
#
# exp-schp-201908261155-lip.pth:  55%|████▉    | 147M/267M [00:09<00:06, 17.4MB/s]
# virtual_tryon_dc.pth:   0%|                | 21.0M/7.21G [00:01<07:15, 16.5MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   0%|                   | 52.4M/20.9G [00:09<58:43, 5.91MB/s]
#
#
#
#
#
# exp-schp-201908301523-atr.pth:  78%|███████  | 210M/267M [00:09<00:02, 23.9MB/s]
#
#
# parsing_lip.onnx:  71%|███████████████▌      | 189M/267M [00:09<00:03, 23.3MB/s]
# virtual_tryon_dc.pth:   0%|                | 31.5M/7.21G [00:02<07:58, 15.0MB/s]
#
#
#
#
# exp-schp-201908261155-lip.pth:  59%|█████▎   | 157M/267M [00:10<00:07, 15.6MB/s]
#
#
#
#
#
# exp-schp-201908301523-atr.pth:  82%|███████▍ | 220M/267M [00:10<00:02, 21.3MB/s]
#
#
# parsing_lip.onnx:  75%|████████████████▍     | 199M/267M [00:10<00:03, 21.7MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   0%|                   | 62.9M/20.9G [00:10<49:54, 6.95MB/s]
#
#
#
#
#
# exp-schp-201908301523-atr.pth:  86%|███████▊ | 231M/267M [00:10<00:01, 22.5MB/s]
#
#
# parsing_lip.onnx:  79%|█████████████████▎    | 210M/267M [00:10<00:02, 22.6MB/s]
# virtual_tryon_dc.pth:   1%|                | 41.9M/7.21G [00:02<07:19, 16.3MB/s]
#
#
#
#
# exp-schp-201908261155-lip.pth:  63%|█████▋   | 168M/267M [00:10<00:06, 16.4MB/s]
#
#
#
#
#
# exp-schp-201908301523-atr.pth:  90%|████████ | 241M/267M [00:10<00:01, 24.1MB/s]
#
#
# parsing_lip.onnx:  83%|██████████████████▏   | 220M/267M [00:11<00:01, 23.4MB/s]
# virtual_tryon_dc.pth:   1%|                | 52.4M/7.21G [00:03<07:02, 16.9MB/s]
#
#
#
#
#
# exp-schp-201908301523-atr.pth:  94%|████████▍| 252M/267M [00:11<00:00, 23.6MB/s]
#
#
#
#
# exp-schp-201908261155-lip.pth:  67%|█████▉   | 178M/267M [00:11<00:05, 16.1MB/s]
#
#
# parsing_lip.onnx:  86%|███████████████████   | 231M/267M [00:11<00:01, 24.1MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   0%|                   | 73.4M/20.9G [00:11<44:31, 7.79MB/s]
#
#
# parsing_lip.onnx:  90%|███████████████████▉  | 241M/267M [00:11<00:01, 24.8MB/s]
#
#
#
#
#
# exp-schp-201908301523-atr.pth:  98%|████████▊| 262M/267M [00:11<00:00, 23.6MB/s]
# virtual_tryon_dc.pth:   1%|▏               | 62.9M/7.21G [00:03<06:50, 17.4MB/s]
#
#
#
#
#
# exp-schp-201908301523-atr.pth: 100%|█████████| 267M/267M [00:12<00:00, 22.1MB/s]
#
#
#
#
#
#
#
# pose_transfer.pth:   0%|                   | 83.9M/20.9G [00:12<36:49, 9.41MB/s]
#
#
#
#
# exp-schp-201908261155-lip.pth:  71%|██████▎  | 189M/267M [00:12<00:05, 15.4MB/s]
#
#
# parsing_lip.onnx:  94%|████████████████████▋ | 252M/267M [00:12<00:00, 24.9MB/s]
# virtual_tryon_dc.pth:   1%|▏               | 73.4M/7.21G [00:04<06:31, 18.2MB/s]
#
#
#
#
#
#
# pose_transfer.pth:
6MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   1%|▎                   | 262M/20.9G [00:16<07:09, 48.0MB/s]
#
#
#
# body_pose_model.pth:  25%|████▌             | 52.4M/209M [00:16<00:55, 2.84MB/s]
# virtual_tryon_dc.pth:   3%|▌                | 220M/7.21G [00:08<02:51, 40.7MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   1%|▎                   | 273M/20.9G [00:16<07:22, 46.5MB/s]
# virtual_tryon_dc.pth:   3%|▌                | 231M/7.21G [00:08<02:48, 41.3MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   1%|▎                   | 283M/20.9G [00:16<07:00, 49.0MB/s]
# virtual_tryon_dc.pth:   3%|▌                | 241M/7.21G [00:08<02:41, 43.3MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   1%|▎                   | 294M/20.9G [00:17<06:59, 49.0MB/s]
# virtual_tryon_dc.pth:   3%|▌                | 252M/7.21G [00:09<02:39, 43.8MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   1%|▎                   | 304M/20.9G [00:17<06:56, 49.4MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   2%|▎                   | 315M/20.9G [00:17<07:10, 47.7MB/s]
# virtual_tryon_dc.pth:   4%|▌                | 262M/7.21G [00:09<02:39, 43.6MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   2%|▎                   | 325M/20.9G [00:17<06:47, 50.4MB/s]
# virtual_tryon_dc.pth:   4%|▋                | 273M/7.21G [00:09<02:31, 45.9MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   2%|▎                   | 336M/20.9G [00:17<06:59, 48.9MB/s]
#
#
#
#
#
#
#
# virtual_tryon.pth:   0%|                 | 21.0M/7.21G [00:14<1:16:18, 1.57MB/s]
# virtual_tryon_dc.pth:   4%|▋                | 283M/7.21G [00:09<02:32, 45.4MB/s]
#
# parsing_atr.onnx:  28%|█████▊               | 73.4M/267M [00:18<01:02, 3.08MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   2%|▎                   | 346M/20.9G [00:18<07:16, 47.1MB/s]
# virtual_tryon_dc.pth:   4%|▋                | 294M/7.21G [00:10<02:29, 46.4MB/s]
#
#
#
# body_pose_model.pth:  30%|█████▍            | 62.9M/209M [00:18<00:42, 3.47MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   2%|▎                   | 357M/20.9G [00:18<07:18, 46.7MB/s]
# virtual_tryon_dc.pth:   4%|▋                | 304M/7.21G [00:10<02:31, 45.6MB/s]
#
#
#
#
#
#
# Fetching 37 files:  30%|███████▏                | 11/37 [00:19<00:27,  1.04s/it]
# virtual_tryon_dc.pth:   4%|▋                | 315M/7.21G [00:10<02:32, 45.2MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   2%|▎                   | 377M/20.9G [00:18<07:07, 48.0MB/s]
# virtual_tryon_dc.pth:   5%|▊                | 325M/7.21G [00:10<02:35, 44.4MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   2%|▎                   | 388M/20.9G [00:19<07:20, 46.5MB/s]
# virtual_tryon_dc.pth:   5%|▊                | 336M/7.21G [00:10<02:30, 45.8MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   2%|▍                   | 398M/20.9G [00:19<07:50, 43.5MB/s]
# virtual_tryon_dc.pth:   5%|▊                | 346M/7.21G [00:11<02:31, 45.3MB/s]
#
#
#
# body_pose_model.pth:  35%|██████▎           | 73.4M/209M [00:19<00:31, 4.33MB/s]
# virtual_tryon_dc.pth:   5%|▊                | 357M/7.21G [00:11<02:34, 44.4MB/s]
#
#
#
#
#
#
#
# virtual_tryon.pth:   0%|                   | 31.5M/7.21G [00:15<49:55, 2.40MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   2%|▍                   | 409M/20.9G [00:19<07:56, 42.9MB/s]
#
# parsing_atr.onnx:  31%|██████▌              | 83.9M/267M [00:19<00:49, 3.67MB/s]
# virtual_tryon_dc.pth:   5%|▊                | 367M/7.21G [00:11<02:30, 45.4MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   2%|▍                   | 419M/20.9G [00:19<08:27, 40.3MB/s]
# virtual_tryon_dc.pth:   5%|▉                | 377M/7.21G [00:11<02:36, 43.6MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   2%|▍                   | 430M/20.9G [00:20<08:15, 41.2MB/s]
# virtual_tryon_dc.pth:   5%|▉                | 388M/7.21G [00:12<02:43, 41.6MB/s]
#
#
#
# body_pose_model.pth:  40%|███████▏          | 83.9M/209M [00:20<00:23, 5.43MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   2%|▍                   | 440M/20.9G [00:20<08:20, 40.8MB/s]
#
#
#
#
#
#
#
# virtual_tryon.pth:   1%|                   | 41.9M/7.21G [00:16<34:34, 3.46MB/s]
# virtual_tryon_dc.pth:   6%|▉                | 398M/7.21G [00:12<02:46, 41.0MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   2%|▍                   | 451M/20.9G [00:20<08:35, 39.6MB/s]
# virtual_tryon_dc.pth:   6%|▉                | 409M/7.21G [00:12<02:48, 40.5MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   2%|▍                   | 461M/20.9G [00:20<08:10, 41.6MB/s]
#
# parsing_atr.onnx:  35%|███████▍             | 94.4M/267M [00:21<00:38, 4.43MB/s]
#
#
#
# body_pose_model.pth:  45%|████████          | 94.4M/209M [00:21<00:17, 6.71MB/s]
# virtual_tryon_dc.pth:   6%|▉                | 419M/7.21G [00:13<02:51, 39.6MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   2%|▍                   | 472M/20.9G [00:21<08:21, 40.7MB/s]
# virtual_tryon_dc.pth:   6%|█                | 430M/7.21G [00:13<02:50, 39.7MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   2%|▍                   | 482M/20.9G [00:21<08:32, 39.8MB/s]
#
#
#
# body_pose_model.pth:  50%|█████████▌         | 105M/209M [00:21<00:12, 8.46MB/s]
#
#
#
#
#
#
#
# virtual_tryon.pth:   1%|▏                  | 52.4M/7.21G [00:17<26:34, 4.49MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   2%|▍                   | 493M/20.9G [00:21<08:31, 39.9MB/s]
# virtual_tryon_dc.pth:   6%|█                | 440M/7.21G [00:13<03:00, 37.6MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   2%|▍                   | 503M/20.9G [00:21<08:21, 40.6MB/s]
# virtual_tryon_dc.pth:   6%|█                | 451M/7.21G [00:13<03:08, 35.9MB/s]
#
#
#
# body_pose_model.pth:  55%|██████████▍        | 115M/209M [00:22<00:09, 10.3MB/s]
#
# parsing_atr.onnx:  39%|████████▋             | 105M/267M [00:22<00:30, 5.29MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   2%|▍                   | 514M/20.9G [00:22<08:34, 39.6MB/s]
# virtual_tryon_dc.pth:   6%|█                | 461M/7.21G [00:14<03:09, 35.6MB/s]
#
#
#
# body_pose_model.pth:  60%|███████████▍       | 126M/209M [00:22<00:06, 12.9MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   3%|▌                   | 524M/20.9G [00:22<09:19, 36.4MB/s]
#
#
#
#
#
#
#
# virtual_tryon.pth:   1%|▏                  | 62.9M/7.21G [00:18<21:16, 5.60MB/s]
# virtual_tryon_dc.pth:   7%|█                | 472M/7.21G [00:14<03:12, 34.9MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   3%|▌                   | 535M/20.9G [00:22<09:24, 36.0MB/s]
#
#
#
# body_pose_model.pth:  65%|████████████▍      | 136M/209M [00:22<00:04, 15.3MB/s]
# virtual_tryon_dc.pth:   7%|█▏               | 482M/7.21G [00:14<03:22, 33.3MB/s]
#
# parsing_atr.onnx:  43%|█████████▌            | 115M/267M [00:23<00:23, 6.32MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   3%|▌                   | 545M/20.9G [00:23<09:43, 34.9MB/s]
#
#
#
# body_pose_model.pth:  70%|█████████████▎     | 147M/209M [00:23<00:03, 18.1MB/s]
# virtual_tryon_dc.pth:   7%|█▏               | 493M/7.21G [00:15<03:22, 33.2MB/s]
#
#
#
#
#
#
#
# virtual_tryon.pth:   1%|▏                  | 73.4M/7.21G [00:19<16:58, 7.01MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   3%|▌                   | 556M/20.9G [00:23<09:54, 34.2MB/s]
#
#
#
# body_pose_model.pth:  75%|██████████████▎    | 157M/209M [00:23<00:02, 19.7MB/s]
# virtual_tryon_dc.pth:   7%|█▏               | 503M/7.21G [00:15<03:24, 32.8MB/s]
#
#
#
# body_pose_model.pth:  80%|███████████████▏   | 168M/209M [00:23<00:01, 22.8MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   3%|▌                   | 566M/20.9G [00:23<11:06, 30.5MB/s]
# virtual_tryon_dc.pth:   7%|█▏               | 514M/7.21G [00:15<03:31, 31.7MB/s]
#
#
#
#
#
#
#
# virtual_tryon.pth:   1%|▏                  | 83.9M/7.21G [00:20<14:02, 8.46MB/s]
#
# parsing_atr.onnx:  47%|██████████▎           | 126M/267M [00:24<00:19, 7.27MB/s]
#
#
#
# body_pose_model.pth:  85%|████████████████▏  | 178M/209M [00:24<00:01, 25.5MB/s]
# virtual_tryon_dc.pth:   7%|█▏               | 524M/7.21G [00:16<03:39, 30.5MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   3%|▌                   | 577M/20.9G [00:24<12:09, 27.8MB/s]
#
#
#
# body_pose_model.pth:  90%|█████████████████▏ | 189M/209M [00:24<00:00, 27.3MB/s]
#
#
#
#
#
#
#
# virtual_tryon.pth:   1%|▏                  | 94.4M/7.21G [00:20<11:50, 10.0MB/s]
# virtual_tryon_dc.pth:   7%|█▎               | 535M/7.21G [00:16<03:39, 30.4MB/s]
#
# parsing_atr.onnx:  51%|███████████▏          | 136M/267M [00:24<00:15, 8.53MB/s]
#
#
#
# body_pose_model.pth:  95%|██████████████████ | 199M/209M [00:24<00:00, 29.5MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   3%|▌                   | 587M/20.9G [00:24<13:00, 26.0MB/s]
#
#
#
# body_pose_model.pth: 100%|███████████████████| 209M/209M [00:25<00:00, 31.3MB/s]
# body_pose_model.pth: 100%|███████████████████| 209M/209M [00:25<00:00, 8.32MB/s]
#
#
#
#
#
#
#
#
# virtual_tryon.pth:   1%|▎                   | 105M/7.21G [00:21<10:09, 11.7MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   3%|▌                   | 598M/20.9G [00:25<12:56, 26.1MB/s]
# virtual_tryon_dc.pth:   8%|█▎               | 556M/7.21G [00:17<03:33, 31.2MB/s]
#
# parsing_atr.onnx:  55%|████████████          | 147M/267M [00:25<00:12, 9.90MB/s]
#
#
#
#
#
#
#
# virtual_tryon.pth:   2%|▎                   | 115M/7.21G [00:21<08:27, 14.0MB/s]
#
# parsing_atr.onnx:  59%|████████████▉         | 157M/267M [00:25<00:08, 12.7MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   3%|▌                   | 608M/20.9G [00:25<15:05, 22.4MB/s]
#
#
#
#
#
#
#
# virtual_tryon.pth:   2%|▎                   | 126M/7.21G [00:22<06:57, 17.0MB/s]
# virtual_tryon_dc.pth:   8%|█▎               | 566M/7.21G [00:17<04:22, 25.3MB/s]
#
# parsing_atr.onnx:  63%|█████████████▊        | 168M/267M [00:26<00:06, 15.5MB/s]
#
#
#
#
#
#
#
# virtual_tryon.pth:   2%|▍                   | 136M/7.21G [00:22<05:54, 20.0MB/s]
#
# parsing_atr.onnx:  67%|██████████████▋       | 178M/267M [00:26<00:04, 18.4MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   3%|▌                   | 619M/20.9G [00:26<17:14, 19.6MB/s]
#
#
#
#
#
#
#
# virtual_tryon.pth:   2%|▍                   | 147M/7.21G [00:22<05:14, 22.5MB/s]
#
# parsing_atr.onnx:  71%|███████████████▌      | 189M/267M [00:26<00:03, 21.4MB/s]
# virtual_tryon_dc.pth:   8%|█▎               | 577M/7.21G [00:18<05:15, 21.0MB/s]
#
# parsing_atr.onnx:  75%|████████████████▍     | 199M/267M [00:27<00:02, 25.0MB/s]
#
#
#
#
#
#
#
# virtual_tryon.pth:   2%|▍                   | 157M/7.21G [00:23<04:58, 23.7MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   3%|▌                   | 629M/20.9G [00:27<17:46, 19.0MB/s]
#
# parsing_atr.onnx:  79%|█████████████████▎    | 210M/267M [00:27<00:02, 28.2MB/s]
# virtual_tryon_dc.pth:   8%|█▍               | 587M/7.21G [00:19<05:21, 20.6MB/s]
#
#
#
#
#
#
#
# virtual_tryon.pth:   2%|▍                   | 168M/7.21G [00:23<04:39, 25.2MB/s]
# virtual_tryon_dc.pth:   8%|█▍               | 598M/7.21G [00:19<04:34, 24.1MB/s]
#
# parsing_atr.onnx:  83%|██████████████████▏   | 220M/267M [00:27<00:01, 25.1MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   3%|▌                   | 640M/20.9G [00:27<17:54, 18.8MB/s]
#
#
#
#
#
#
#
# virtual_tryon.pth:   2%|▍                   | 178M/7.21G [00:24<04:48, 24.4MB/s]
# virtual_tryon_dc.pth:   8%|█▍               | 608M/7.21G [00:19<04:17, 25.6MB/s]
#
# parsing_atr.onnx:  86%|███████████████████   | 231M/267M [00:28<00:01, 27.0MB/s]
#
#
#
#
#
#
#
# virtual_tryon.pth:   3%|▌                   | 189M/7.21G [00:24<04:35, 25.5MB/s]
# virtual_tryon_dc.pth:   9%|█▍               | 619M/7.21G [00:20<04:04, 27.0MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   3%|▌                   | 650M/20.9G [00:28<17:03, 19.8MB/s]
#
# parsing_atr.onnx:  90%|███████████████████▉  | 241M/267M [00:28<00:00, 29.2MB/s]
#
#
#
#
#
#
#
# virtual_tryon.pth:   3%|▌                   | 199M/7.21G [00:24<04:12, 27.8MB/s]
# virtual_tryon_dc.pth:   9%|█▍               | 629M/7.21G [00:20<04:05, 26.8MB/s]
#
# parsing_atr.onnx:  94%|████████████████████▋ | 252M/267M [00:28<00:00, 30.3MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   3%|▋                   | 661M/20.9G [00:28<17:07, 19.7MB/s]
#
#
#
#
#
#
#
# virtual_tryon.pth:   3%|▌                   | 210M/7.21G [00:25<04:01, 29.0MB/s]
#
# parsing_atr.onnx:  98%|█████████████████████▌| 262M/267M [00:29<00:00, 31.7MB/s]
# virtual_tryon_dc.pth:   9%|█▌               | 640M/7.21G [00:20<04:02, 27.1MB/s]
#
# parsing_atr.onnx: 100%|██████████████████████| 267M/267M [00:29<00:00, 31.8MB/s]
#
#
#
#
#
#
#
# parsing_atr.onnx: 100%|██████████████████████| 267M/267M [00:29<00:00, 9.12MB/s]
# Fetching 37 files:  65%|███████████████▌        | 24/37 [00:30<00:18,  1.44s/it]
#
#
#
#
#
#
# pose_transfer.pth:   3%|▋                   | 671M/20.9G [00:29<16:33, 20.3MB/s]
# virtual_tryon_dc.pth:   9%|█▌               | 650M/7.21G [00:21<03:53, 28.1MB/s]
#
#
#
#
#
#
#
# virtual_tryon.pth:   3%|▋                   | 231M/7.21G [00:25<03:33, 32.6MB/s]
# virtual_tryon_dc.pth:   9%|█▌               | 661M/7.21G [00:21<03:37, 30.1MB/s]
#
#
#
#
#
#
#
# virtual_tryon.pth:   3%|▋                   | 241M/7.21G [00:25<03:18, 35.1MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   3%|▋                   | 682M/20.9G [00:29<15:35, 21.6MB/s]
# virtual_tryon_dc.pth:   9%|█▌               | 671M/7.21G [00:21<03:17, 33.1MB/s]
#
#
#
#
#
#
#
# virtual_tryon.pth:   3%|▋                   | 252M/7.21G [00:26<03:08, 36.9MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   3%|▋                   | 692M/20.9G [00:29<14:35, 23.1MB/s]
# virtual_tryon_dc.pth:   9%|█▌               | 682M/7.21G [00:21<03:06, 35.0MB/s]
#
#
#
#
#
#
#
# virtual_tryon.pth:   4%|▋                   | 262M/7.21G [00:26<02:59, 38.7MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   3%|▋                   | 703M/20.9G [00:30<13:05, 25.7MB/s]
# virtual_tryon_dc.pth:  10%|█▋               | 692M/7.21G [00:22<03:05, 35.1MB/s]
#
#
#
#
#
#
#
# virtual_tryon.pth:   4%|▊                   | 273M/7.21G [00:26<03:03, 37.9MB/s]
#
#
#
#
#
#
# pose_transfer.pth:   3%|
 102MB/s]
#
#
#
#
#
#
# pose_transfer.pth:  99%|███████████████████▋| 20.6G/20.9G [06:01<00:02, 102MB/s]
#
#
#
#
#
#
# pose_transfer.pth:  99%|███████████████████▋| 20.6G/20.9G [06:01<00:02, 102MB/s]
#
#
#
#
#
#
# pose_transfer.pth:  99%|██████████████████▊| 20.6G/20.9G [06:02<00:03, 74.0MB/s]
#
#
#
#
#
#
# pose_transfer.pth:  99%|██████████████████▊| 20.6G/20.9G [06:02<00:02, 81.6MB/s]
#
#
#
#
#
#
# pose_transfer.pth:  99%|██████████████████▊| 20.7G/20.9G [06:02<00:02, 85.4MB/s]
#
#
#
#
#
#
# pose_transfer.pth:  99%|██████████████████▊| 20.7G/20.9G [06:02<00:02, 90.9MB/s]
#
#
#
#
#
#
# pose_transfer.pth:  99%|██████████████████▊| 20.7G/20.9G [06:03<00:01, 96.6MB/s]
#
#
#
#
#
#
# pose_transfer.pth:  99%|██████████████████▊| 20.7G/20.9G [06:03<00:01, 97.4MB/s]
#
#
#
#
#
#
# pose_transfer.pth:  99%|██████████████████▊| 20.7G/20.9G [06:03<00:01, 95.4MB/s]
#
#
#
#
#
#
# pose_transfer.pth:  99%|██████████████████▉| 20.8G/20.9G [06:03<00:01, 99.9MB/s]
#
#
#
#
#
#
# pose_transfer.pth:  99%|██████████████████▉| 20.8G/20.9G [06:03<00:01, 99.6MB/s]
#
#
#
#
#
#
# pose_transfer.pth: 100%|██████████████████▉| 20.8G/20.9G [06:03<00:01, 99.4MB/s]
#
#
#
#
#
#
# pose_transfer.pth: 100%|███████████████████▉| 20.8G/20.9G [06:03<00:00, 100MB/s]
#
#
#
#
#
#
# pose_transfer.pth: 100%|██████████████████▉| 20.8G/20.9G [06:04<00:00, 98.3MB/s]
#
#
#
#
#
#
# pose_transfer.pth: 100%|███████████████████▉| 20.8G/20.9G [06:04<00:00, 102MB/s]
#
#
#
#
#
#
# pose_transfer.pth: 100%|███████████████████▉| 20.8G/20.9G [06:04<00:00, 101MB/s]
#
#
#
#
#
#
# pose_transfer.pth: 100%|███████████████████▉| 20.9G/20.9G [06:04<00:00, 101MB/s]
#
#
#
#
#
#
# pose_transfer.pth: 100%|███████████████████| 20.9G/20.9G [06:04<00:00, 57.2MB/s]
# Fetching 37 files: 100%|████████████████████████| 37/37 [06:06<00:00,  9.90s/it]
# The config attributes {'decay': 0.9999, 'inv_gamma': 1.0, 'min_decay': 0.0, 'optimization_step': 37000, 'power': 0.6666666666666666, 'update_after_step': 0, 'use_ema_warmup': False} were passed to UNet2DConditionModel, but are not expected and will be ignored. Please verify your config.json configuration file.
# The config attributes {'decay': 0.9999, 'inv_gamma': 1.0, 'min_decay': 0.0, 'optimization_step': 37000, 'power': 0.6666666666666666, 'update_after_step': 0, 'use_ema_warmup': False} were passed to UNet2DConditionModel, but are not expected and will be ignored. Please verify your config.json configuration file.
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://882e9770ea22893d10.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)

# %%
# %cd leffa
# Out:
# /content/leffa

# %%
#3rdparty   app.py      in_img				 leffa_utils
#LICENSE    ckpts       leffa				 preprocess
#README.md  densepose   leffa_test.ipynb			 requirements.txt
#SCHP	   detectron2  leffa_test.ipynb:Zone.Identifier  vton_script.py

# %%
# !ls
# Out:
# 3rdparty   app.py      in_img				 leffa_utils
# LICENSE    ckpts       leffa				 preprocess
# README.md  densepose   leffa_test.ipynb			 requirements.txt
# SCHP	   detectron2  leffa_test.ipynb:Zone.Identifier  vton_script.py

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
from vton_script import LeffaVirtualTryOn
from IPython.display import display

vton = LeffaVirtualTryOn(ckpt_dir="./ckpts")

gen_img, mask_img, dense_img = vton.run(
    person_image_path="in_img/upper_img2.jpg",
    garment_image_path="in_img/09133_00.jpg",
    output_path="output/virtual_tryon_result.jpg",
    garment_type="upper_body",
    repaint=False,
    preprocess_garment=False  # PNG 파일이면 True 가능
)

display(gen_img)
display(mask_img)
display(dense_img)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.86it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.45it/s]
# /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages/torch/functional.py:539: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#  37%|██████████████████████████████▍                                                    | 11/30 [05:56<10:16, 32.43s/it]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 6
#       2 from IPython.display import display
#       4 vton = LeffaVirtualTryOn(ckpt_dir="./ckpts")
# ----> 6 gen_img, mask_img, dense_img = vton.run(
#       7     person_image_path="in_img/upper_img2.jpg",
#       8     garment_image_path="in_img/09133_00.jpg",
#       9     output_path="output/virtual_tryon_result.jpg",
#      10     garment_type="upper_body",
#      11     repaint=False,
#      12     preprocess_garment=False  # PNG 파일이면 True 가능
#      13 )
#      15 display(gen_img)
#      16 display(mask_img)
#
# File ~/Leffa/vton_script.py:102, in LeffaVirtualTryOn.run(self, person_image_path, garment_image_path, output_path, garment_type, repaint, model_type, preprocess_garment, step, scale, seed)
#      99 data = transform(data)
#     101 inference = self.vt_inference_hd if model_type == "viton_hd" else self.vt_inference_dc
# --> 102 result = inference(
#     103     data,
#     104     ref_acceleration=False,
#     105     num_inference_steps=step,
#     106     guidance_scale=scale,
#     107     seed=seed,
#     108     repaint=repaint
#     109 )
#     110 gen_image = result["generated_image"][0]
#     112 if output_path:
#
# File ~/Leffa/leffa/inference.py:42, in LeffaInference.__call__(self, data, **kwargs)
#      40 repaint = kwargs.get("repaint", False)
#      41 generator = torch.Generator(self.pipe.device).manual_seed(seed)
# ---> 42 images = self.pipe(
#      43     src_image=data["src_image"],
#      44     ref_image=data["ref_image"],
#      45     mask=data["mask"],
#      46     densepose=data["densepose"],
#      47     ref_acceleration=ref_acceleration,
#      48     num_inference_steps=num_inference_steps,
#      49     guidance_scale=guidance_scale,
#      50     generator=generator,
#      51     repaint=repaint,
#      52 )[0]
#      54 # images = [pil_to_tensor(image) for image in images]
#      55 # images = torch.stack(images)
#      57 outputs = {}
#
# File ~/anaconda3/envs/leffa/lib/python3.10/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/Leffa/leffa/pipeline.py:138, in LeffaPipeline.__call__(self, src_image, ref_image, mask, densepose, ref_acceleration, num_inference_steps, do_classifier_free_guidance, guidance_scale, generator, eta, repaint, **kwargs)
#     135     reference_features = list(reference_features)
#     137 # predict the noise residual
# --> 138 noise_pred = self.unet(
#     139     latent_model_input,
#     140     t,
#     141     encoder_hidden_states=None,
#     142     cross_attention_kwargs=None,
#     143     added_cond_kwargs=None,
#     144     reference_features=reference_features,
#     145     return_dict=False,
#     146 )[0]
#     147 # perform guidance
#     148 if do_classifier_free_guidance:
#
# File ~/anaconda3/envs/leffa/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/leffa/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Leffa/leffa/diffusion_model/unet_gen.py:1357, in UNet2DConditionModel.forward(self, sample, timestep, encoder_hidden_states, class_labels, timestep_cond, attention_mask, cross_attention_kwargs, added_cond_kwargs, down_block_additional_residuals, mid_block_additional_residual, down_intrablock_additional_residuals, encoder_attention_mask, return_dict, reference_features)
#    1351     upsample_size = down_block_res_samples[-1].shape[2:]
#    1353 if (
#    1354     hasattr(upsample_block, "has_cross_attention")
#    1355     and upsample_block.has_cross_attention
#    1356 ):
# -> 1357     sample, this_reference_feature_idx = upsample_block(
#    1358         hidden_states=sample,
#    1359         temb=emb,
#    1360         res_hidden_states_tuple=res_samples,
#    1361         encoder_hidden_states=encoder_hidden_states,
#    1362         cross_attention_kwargs=cross_attention_kwargs,
#    1363         upsample_size=upsample_size,
#    1364         attention_mask=attention_mask,
#    1365         encoder_attention_mask=encoder_attention_mask,
#    1366         reference_features=reference_features,
#    1367         this_reference_feature_idx=this_reference_feature_idx,
#    1368     )
#    1370 else:
#    1371     sample = upsample_block(
#    1372         hidden_states=sample,
#    1373         temb=emb,
#    (...)
#    1376         scale=lora_scale,
#    1377     )
#
# File ~/anaconda3/envs/leffa/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/leffa/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Leffa/leffa/diffusion_model/unet_block_gen.py:2527, in CrossAttnUpBlock2D.forward(self, hidden_states, res_hidden_states_tuple, temb, encoder_hidden_states, cross_attention_kwargs, upsample_size, attention_mask, encoder_attention_mask, reference_features, this_reference_feature_idx)
#    2525     else:
#    2526         hidden_states = resnet(hidden_states, temb, scale=lora_scale)
# -> 2527         hidden_states, this_reference_feature_idx = attn(
#    2528             hidden_states,
#    2529             encoder_hidden_states=encoder_hidden_states,
#    2530             cross_attention_kwargs=cross_attention_kwargs,
#    2531             attention_mask=attention_mask,
#    2532             encoder_attention_mask=encoder_attention_mask,
#    2533             return_dict=False,
#    2534             reference_features=reference_features,
#    2535             this_reference_feature_idx=this_reference_feature_idx,
#    2536         )
#    2537         hidden_states = hidden_states[0]
#    2538 if self.upsamplers is not None:
#
# File ~/anaconda3/envs/leffa/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/leffa/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Leffa/leffa/diffusion_model/transformer_gen.py:465, in Transformer2DModel.forward(self, hidden_states, encoder_hidden_states, timestep, added_cond_kwargs, class_labels, cross_attention_kwargs, attention_mask, encoder_attention_mask, reference_features, this_reference_feature_idx, return_dict)
#     449         hidden_states, this_reference_feature_idx = (
#     450             torch.utils.checkpoint.checkpoint(
#     451                 create_custom_forward(block),
#    (...)
#     462             )
#     463         )
#     464     else:
# --> 465         hidden_states, this_reference_feature_idx = block(
#     466             hidden_states,
#     467             attention_mask=attention_mask,
#     468             encoder_hidden_states=encoder_hidden_states,
#     469             encoder_attention_mask=encoder_attention_mask,
#     470             timestep=timestep,
#     471             cross_attention_kwargs=cross_attention_kwargs,
#     472             class_labels=class_labels,
#     473             reference_features=reference_features,
#     474             this_reference_feature_idx=this_reference_feature_idx,
#     475         )
#     477 # 3. Output
#     478 if self.is_input_continuous:
#
# File ~/anaconda3/envs/leffa/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/leffa/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Leffa/leffa/diffusion_model/attention_gen.py:381, in BasicTransformerBlock.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, timestep, cross_attention_kwargs, class_labels, reference_features, this_reference_feature_idx, added_cond_kwargs)
#     377 modify_norm_hidden_states = torch.cat(
#     378     [norm_hidden_states, reference_features[this_reference_feature_idx]], dim=1
#     379 )
#     380 this_reference_feature_idx += 1
# --> 381 attn_output = self.attn1(
#     382     modify_norm_hidden_states,
#     383     encoder_hidden_states=(
#     384         encoder_hidden_states if self.only_cross_attention else None
#     385     ),
#     386     attention_mask=attention_mask,
#     387     **cross_attention_kwargs,
#     388 )
#     389 if self.use_ada_layer_norm_zero:
#     390     attn_output = gate_msa.unsqueeze(1) * attn_output
#
# File ~/anaconda3/envs/leffa/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/leffa/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/leffa/lib/python3.10/site-packages/diffusers/models/attention_processor.py:605, in Attention.forward(self, hidden_states, encoder_hidden_states, attention_mask, **cross_attention_kwargs)
#     600     logger.warning(
#     601         f"cross_attention_kwargs {unused_kwargs} are not expected by {self.processor.__class__.__name__} and will be ignored."
#     602     )
#     603 cross_attention_kwargs = {k: w for k, w in cross_attention_kwargs.items() if k in attn_parameters}
# --> 605 return self.processor(
#     606     self,
#     607     hidden_states,
#     608     encoder_hidden_states=encoder_hidden_states,
#     609     attention_mask=attention_mask,
#     610     **cross_attention_kwargs,
#     611 )
#
# File ~/Leffa/leffa/model.py:347, in AttnProcessor2_0.__call__(self, attn, hidden_states, encoder_hidden_states, attention_mask, temb, *args, **kwargs)
#     344 hidden_states = hidden_states.to(query.dtype)
#     346 # linear proj
# --> 347 hidden_states = attn.to_out[0](hidden_states)
#     348 # dropout
#     349 hidden_states = attn.to_out[1](hidden_states)
#
# File ~/anaconda3/envs/leffa/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/leffa/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/leffa/lib/python3.10/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: CUDA error: CUBLAS_STATUS_EXECUTION_FAILED when calling cublasLtMatmul with transpose_mat1 1 transpose_mat2 0 m 1280 n 3072 k 1280 mat1_ld 1280 mat2_ld 1280 result_ld 1280 abcType 2 computeType 68 scaleType 0

# %%
from vton_script import LeffaVirtualTryOn
from IPython.display import display

vton = LeffaVirtualTryOn(ckpt_dir="./ckpts")

output_image, mask, densepose = vton.leffa_predict(
    src_image_path="in_img/upper_img5.jpg",
    ref_image_path="in_img/09133_00.jpg",
    control_type="virtual_tryon",
    vt_model_type="viton_hd",
    vt_garment_type="upper_body"
)
output_image.show()
# Out:
# /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages/torch/functional.py:539: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#   0%|                                                                                            | 0/30 [00:00<?, ?it/s]/home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages/diffusers/models/resnet.py:323: FutureWarning: `scale` is deprecated and will be removed in version 1.0.0. The `scale` argument is deprecated and will be ignored. Please remove it, as passing it will raise an error in the future. `scale` should directly be passed while calling the underlying pipeline component i.e., via `cross_attention_kwargs`.
#   deprecate("scale", "1.0.0", deprecation_message)
# /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages/diffusers/models/activations.py:116: FutureWarning: `scale` is deprecated and will be removed in version 1.0.0. The `scale` argument is deprecated and will be ignored. Please remove it, as passing it will raise an error in the future. `scale` should directly be passed while calling the underlying pipeline component i.e., via `cross_attention_kwargs`.
#   deprecate("scale", "1.0.0", deprecation_message)
# /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages/diffusers/models/downsampling.py:135: FutureWarning: `scale` is deprecated and will be removed in version 1.0.0. The `scale` argument is deprecated and will be ignored. Please remove it, as passing it will raise an error in the future. `scale` should directly be passed while calling the underlying pipeline component i.e., via `cross_attention_kwargs`.
#   deprecate("scale", "1.0.0", deprecation_message)
# /home/lab/anaconda3/envs/leffa/lib/python3.10/site-packages/diffusers/models/upsampling.py:145: FutureWarning: `scale` is deprecated and will be removed in version 1.0.0. The `scale` argument is deprecated and will be ignored. Please remove it, as passing it will raise an error in the future. `scale` should directly be passed while calling the underlying pipeline component i.e., via `cross_attention_kwargs`.
#   deprecate("scale", "1.0.0", deprecation_message)
# 100%|███████████████████████████████████████████████████████████████████████████████████| 30/30 [02:57<00:00,  5.91s/it]
# <PIL.Image.Image image mode=RGB size=768x1024>

# %%
display(output_image)

display(mask)

display(densepose)
# Out:
# <PIL.Image.Image image mode=RGB size=768x1024>
# <PIL.Image.Image image mode=L size=768x1024>
# <PIL.Image.Image image mode=RGB size=768x1024>
